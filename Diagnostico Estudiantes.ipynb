# %%
class Estudiante_Datos_Personales():
    def __init__(self, nombre, estado_civil, nacionalidad, calle, numero, colonia, codigo_postal, telefono):
        self.nombre = nombre
        self.estado_civil = estado_civil
        self.nacionalidad = nacionalidad
        self.calle= calle
        self.numero = numero
        self.colonia = colonia
        self.codigo_postal = codigo_postal
        self.telefono = telefono

    def nombre_estudiante(self):
        return f'El estudiante  se llama {self.nombre}.'
    def estado_civil_estudiante(self):
        return f'El estudiante esta {self.estado_civil}.'
    def nacionalidad_estudiante(self):
        return f'El estudiantes es {self.nacionalidad}.'
    def calle_estudiante(self):
        return f'El estudiante vive en la calle {self.calle}.'
    def numero_calle(self):
        return f'Con numero {self.numero}.'
    def colonia_estudiante(self):
        return f'En la colonia {self.colonia}.'
    def codigo_postal_estudiante(self):
        return f'Con codigo postal {self.codigo_postal}.'
    def telefono_estudiante(self):
        return f'Y tiene el numero telefonico {self.telefono}'

class Estudiante_Fisico():
    def __init__(self, edad, sexo, peso, altura, tonalidad_piel, color_ojos, color_cabello):
        self.edad = edad
        self.sexo = sexo
        self.peso = peso
        self.altura = altura
        self.tonalidad_piel = tonalidad_piel
        self.color_ojos = color_ojos
        self.color_cabello = color_cabello
    
    def edad_estudiante(self):
        return f'La edad del estudiante es {self.edad}.'
    def sexo_estudiante(self):
        return f'El sexo del estudiante es {self.sexo}.'
    def peso_estudiante(self):
        return f'El peso del estudiante es {self.peso}.'
    def altura_estudiante(self):
        return f'La altura del estudiante es {self.altura}.'
    def tonalidad_estudiante(self):
        return f'La tonalidad de piel del estudiante es {self.tonalidad_piel}.'
    def color_ojos_estudiante(self):
        return f'El color de ojos del estudiante es {self.color_ojos}.'
    def color_cabello_estudiante(self):
        return f'El color de cabello del estudiante es {self.color_cabello}.'

class Estudiante_Academico():
    def __init__(self, calificaciones_mate, calificaciones_espaniol, calificaciones_quimica, calificaciones_fisica, calificaciones_biologia, calificaciones_geografia, calificaciones_literatura, calificaciones_historia):
        self.calificaciones_mate = calificaciones_mate
        self.calificaciones_espaniol = calificaciones_espaniol
        self.calificaciones_quimica = calificaciones_quimica
        self.calificaciones_fisica = calificaciones_fisica
        self.calificaciones_biologia = calificaciones_biologia
        self.calificaciones_geografia = calificaciones_geografia
        self.calificaciones_literatura = calificaciones_literatura
        self.calificaciones_historia = calificaciones_historia
    def estudiante_matematicas(self):
        return f'La calificacion del estudiante en matematicas es de {self.calificaciones_mate}.'
    def estudiante_espaniol(self):
        return f'La calificacion del estudiante en espaniol es de {self.calificaciones_espaniol}.'
    def estudiante_quimica(self):
        return f'La calificacion del estudiante en quimica es de {self.calificaciones_quimica}.'
    def estudiante_fisica(self):
        return f'La calificacion del estudiante en fisica es de {self.calificaciones_fisica}.'
    def estudiante_biologia(self):
        return f'La calificacion del estudiante en biologia es de {self.calificaciones_biologia}.'
    def estudiante_geografia(self):
        return f'La calificacion del estudiante en geografia es de {self.calificaciones_geografia}.'
    def estudiante_literatura(self):
        return f'La calificacion del estudiante en literatura es de {self.calificaciones_literatura}.'
    def estudiante_historia(self):
        return f'La calificacion del estudiante en historia es de {self.calificaciones_historia}.'
    

class Estudiante_Emocional():
    def __init__(self, autoestima, riesiliencia, relacion_interpersonal, estres, ansiedad, depresion, satisfaccion, cuidado_personal):
        self.autoestima = autoestima
        self.riesiliencia =riesiliencia
        self.relacion_interpersonal = relacion_interpersonal
        self.estres = estres
        self.ansiedad = ansiedad
        self.depresion = depresion
        self.satisfaccion = satisfaccion
        self.cuidado_personal = cuidado_personal
    def autoestima_estudiante(self):
        print('Ingrese valores del 1 al 5 para evaluar la autoestima contando como 1 el valor mas bajo y el 5 como el valor mas alto.')
        if self.autoestima == 5:
            return 'La autoestima del estudiante es alta.'
        elif self.autoestima == 4:
            return 'La autoestima del estudiante es buena.'
        elif self.autoestima == 3:
            return 'El estudiante no tiene una autoestima alta, pero tampoco baja.'
        elif self.autoestima == 2:
            return 'La autoestima del estudiante es baja.'
        elif self.autoestima == 1:
            return 'La autoestima del estudiante necesita revisarse inmediatamente.'
        else:
            return 'Error, solo se aceptan valores numericos del 1 al 5.'
    def riesiliencia_estudiante(self):
        print('Ingrese valores del 1 al 5 para evaluar la riesiliencia contando como 1 el valor mas bajo y el 5 como el valor mas alto.')
        if self.riesiliencia == 5:
            return 'La riesiliencia del estudiante es alta.'
        elif self.riesiliencia == 4:
            return 'La riesilienciadel estudiante es buena.'
        elif self.riesiliencia == 3:
            return 'El estudiante no tiene una riesiliencia alta, pero tampoco baja.'
        elif self.riesiliencia == 2:
            return 'La riesiliencia del estudiante es baja.'
        elif self.riesiliencia == 1:
            return 'La riesiliencia del estudiante necesita revisarse inmediatamente.'
        else:
            return 'Error, solo se aceptan valores numericos del 1 al 5.'
    def relacion_interpersonal_estudiante(self):
        print('Ingrese valores del 1 al 5 para evaluar la relacion interpersonal contando como 1 el valor mas bajo y el 5 como el valor mas alto.')
        if self.relacion_interpersonal == 5:
            return 'La relacion interpersonal del estudiante es alta.'
        elif self.relacion_interpersonal == 4:
            return 'La relacion interpersonal estudiante es buena.'
        elif self.relacion_interpersonal == 3:
            return 'El estudiante no tiene una relacion interpersonalalta, pero tampoco baja.'
        elif self.relacion_interpersonal == 2:
            return 'La relacion interpersonal del estudiante es baja.'
        elif self.relacion_interpersonal == 1:
            return 'La relacion interpersonal del estudiante necesita revisarse inmediatamente.'
        else:
            return 'Error, solo se aceptan valores numericos del 1 al 5.'
    def estres_estudiante(self):
        print('Ingrese valores del 1 al 5 para evaluar el estres contando como 1 el valor mas bajo y el 5 como el valor mas alto.')
        if self.estres == 5:
            return 'El estres del estudiante es alta.'
        elif self.estres== 4:
            return 'El estres estudiante es buena.'
        elif self.estres == 3:
            return 'El estudiante no tiene estres alto, pero tampoco baja.'
        elif self.estres == 2:
            return 'El estres del estudiante es baja.'
        elif self.estres == 1:
            return 'El estres del estudiante necesita revisarse inmediatamente.'
        else:
            return 'Error, solo se aceptan valores numericos del 1 al 5.'
    def ansiedad_estudiante(self):
        print('Ingrese valores del 1 al 5 para evaluar la ansiedad contando como 1 el valor mas bajo y el 5 como el valor mas alto.')
        if self.ansiedad == 5:
            return 'La ansiedad del estudiante es alta.'
        elif self.ansiedad == 4:
            return 'La ansiedad estudiante es buena.'
        elif self.ansiedad  == 3:
            return 'El estudiante no tiene ansiedad alta, pero tampoco baja.'
        elif self.ansiedad  == 2:
            return 'La ansiedad del estudiante es baja.'
        elif self.ansiedad == 1:
            return 'La ansiedad del estudiante necesita revisarse inmediatamente.'
        else:
            return 'Error, solo se aceptan valores numericos del 1 al 5.'
    def depresion_estudiante(self):
        print('Ingrese valores del 1 al 5 para evaluar la depresion contando como 1 el valor mas bajo y el 5 como el valor mas alto.')
        if self.depresion == 5:
            return 'La depresion del estudiante es alta.'
        elif self.depresion == 4:
            return 'La depresion estudiante es buena.'
        elif self.depresion  == 3:
            return 'El estudiante no tiene depresion alta, pero tampoco baja.'
        elif self.depresion  == 2:
            return 'La depresion del estudiante es baja.'
        elif self.depresion == 1:
            return 'La depresion del estudiante necesita revisarse inmediatamente.'
        else:
            return 'Error, solo se aceptan valores numericos del 1 al 5.'
    def satisfaccion_estudiante(self):
        print('Ingrese valores del 1 al 5 para evaluar la satisfaccion contando como 1 el valor mas bajo y el 5 como el valor mas alto.')
        if self.satisfaccion == 5:
            return 'La satisfaccion del estudiante es alta.'
        elif self.satisfaccion == 4:
            return 'La satisfaccion estudiante es buena.'
        elif self.satisfaccion  == 3:
            return 'El estudiante no tiene satisfaccion alta, pero tampoco baja.'
        elif self.satisfaccion  == 2:
            return 'La satisfaccion del estudiante es baja.'
        elif self.satisfaccion == 1:
            return 'La satisfaccion del estudiante necesita revisarse inmediatamente.'
        else:
            return 'Error, solo se aceptan valores numericos del 1 al 5.'
    def cuidado_personal_estudiante(self):
        print('Ingrese valores del 1 al 5 para evaluar el cuidado personal contando como 1 el valor mas bajo y el 5 como el valor mas alto.')
        if self.cuidado_personal == 5:
            return 'El cuidado personal del estudiante es alto.'
        elif self.cuidado_personal == 4:
            return 'El cuidado personal  estudiante es bueno.'
        elif self.cuidado_personal  == 3:
            return 'El estudiante no tiene cuidado personal alto, pero tampoco bajo.'
        elif self.cuidado_personal  == 2:
            return 'El cuidado personal del estudiante es bajo.'
        elif self.cuidado_personal == 1:
            return 'El cuidado personal del estudiante necesita revisarse inmediatamente.'
        else:
            return 'Error, solo se aceptan valores numericos del 1 al 5.'
